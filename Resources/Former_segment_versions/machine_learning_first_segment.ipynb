# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/phacket"
engine = create_engine(db_string)
df = pd.read_sql_table('happy_bills', engine)
df.head(20)
# Out:
#                      reference                 country  year  life_ladder  \
# 0              2016Afghanistan             Afghanistan  2016        4.220
# 1                  2016Albania                 Albania  2016        4.511
# 2                  2016Algeria                 Algeria  2016        5.341
# 3                2016Argentina               Argentina  2016        6.427
# 4                  2016Armenia                 Armenia  2016        4.325
# 5                2016Australia               Australia  2016        7.250
# 6                  2016Austria                 Austria  2016        7.048
# 7               2016Azerbaijan              Azerbaijan  2016        5.304
# 8                  2016Bahrain                 Bahrain  2016        6.170
# 9               2016Bangladesh              Bangladesh  2016        4.556
# 10                 2016Belarus                 Belarus  2016        5.178
# 11                 2016Belgium                 Belgium  2016        6.949
# ...
